# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cl = pd.read_csv("../data/tracks/kart_centerline.csv")
plt.plot(cl["x_m"], cl["y_m"])
plt.axis("equal")
plt.title("Kart Track Centerline")
plt.show()
